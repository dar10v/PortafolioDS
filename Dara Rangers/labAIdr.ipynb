# %% [markdown]
# # Practicas de computer vision

# %%
# Establecemos nuestras credenciales
key ='4d32767efc78483a9b9a2bb139201403'
endpoint ='https://cv-dr-lab01-dario.cognitiveservices.azure.com/'
# conectamos con azure
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

client= ComputerVisionClient(endpoint, CognitiveServicesCredentials(key))

# %%
import vision
import os

# %matplotlib inline

# obtener la imagen
image_path ="./imagen1.jpg"

image_stream = open(image_path, "rb")
description = client.describe_image_in_stream(image_stream)
print(description
)
vision.show_image_caption(image_path, description)

# %%
image_path = "./imagen2.png"
image_stream = open(image_path, "rb")
description = client.describe_image_in_stream(image_stream)
print(description
)
vision.show_image_caption(image_path, description)

# %%
image_path = "./imagen3.jpg"
features = ["Description", "Tags", "Adult", "Objects", "Faces"]

image_stream=open(image_path,"rb")
analysis = client.analyze_image_in_stream(image_stream, visual_features=features)

vision.show_image_analysis(image_path, analysis)

# %%
image_path = "./imagen6.jpg"
features = ["Description", "Tags", "Adult", "Objects", "Faces"]

image_stream=open(image_path,"rb")
analysis = client.analyze_image_in_stream(image_stream, visual_features=features)

vision.show_image_analysis(image_path, analysis)

# %% [markdown]
# # Face api
# !pip install azure-cognitiveservices-vision-face

# %%
key = "a330da2532ac45dc96e2bdd002cb5fca"
endpoint = "https://fa-dr-darop.cognitiveservices.azure.com/"
# conectamos con azure
from azure.cognitiveservices.vision.face import FaceClient
from msrest.authentication import CognitiveServicesCredentials

client= FaceClient(endpoint, CognitiveServicesCredentials(key))

# %%
import os
import faces
# %matplotlib inline

image_path = "./imagen2.png"
image_stream = open(image_path, "rb")
detected_faces = client.face.detect_with_stream(image = image_stream)

faces.show_faces(image_path, detected_faces)

# %%
image_path = "./imagen1.jpg"
image_stream = open(image_path, "rb")
detected_faces = client.face.detect_with_stream(image = image_stream)

faces.show_faces(image_path, detected_faces, show_id=True)

# %%
image_path = "./imagen4.jpg"
image_stream = open(image_path, "rb")

attributes = ["age", "emotion"]
detected_faces = client.face.detect_with_stream(image = image_stream,return_face_attributes=attributes)

faces.show_face_attributes(image_path,detected_faces)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Dario\Documents\Escuela Dario\z900\labai\labAIdr.ipynb Cell 12' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Dario/Documents/Escuela%20Dario/z900/labai/labAIdr.ipynb#ch0000011?line=3'>4</a> attributes = ["age", "emotion"]
#       <a href='vscode-notebook-cell:/c%3A/Users/Dario/Documents/Escuela%20Dario/z900/labai/labAIdr.ipynb#ch0000011?line=4'>5</a> detected_faces = client.face.detect_with_stream(image = image_stream,return_face_attributes=attributes)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dario/Documents/Escuela%20Dario/z900/labai/labAIdr.ipynb#ch0000011?line=6'>7</a> faces.show_faces_attributes(image_path, detected_faces)
#
# AttributeError: module 'faces' has no attribute 'show_faces_attributes'
